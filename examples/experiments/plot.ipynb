# %%
# !pip3 install seaborn
# !pip3 install pandas

# %%
import pandas as pd
import seaborn as sns

sns.set()

# %% [markdown]
# ## Actor scalability (exp1)

# %%
df_exp1 = pd.read_csv('exp1.csv', sep=';')
df_exp1.shape
# Out:
# (10000, 2)

# %%
df_exp1['timeMs'] = df_exp1['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp1['timeMs'])
ax.set_ylim(0, 5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ## Registration scaleability (exp2)

# %%
df_exp2 = pd.read_csv('exp2.csv', sep=';')
df_exp2.shape
# Out:
# (10000, 2)

# %%
df_exp2['timeMs'] = df_exp2['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp2['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
ax = sns.lineplot(data=df_exp2['timeMs'])
ax.set_ylim(0, 200)
ax.set_xlim(0, 5000)
# Out:
# (0.0, 5000.0)

# %%
### Exp2a (only 5000 actors with a 10second brake after 2500)

# %%
df_exp2a = pd.read_csv('exp2a.csv', sep=';')
df_exp2a.shape
# Out:
# (5000, 2)

# %%
df_exp2a['timeMs'] = df_exp2a['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp2a['timeMs'])
ax.set_ylim(0, 200)
ax.set_xlim(0, 5000)
# Out:
# (0.0, 5000.0)

# %% [markdown]
# ## Reminder scalability for deactivated actors that have reminders (exp3)

# %%
df_exp3 = pd.read_csv('exp3.csv', sep=';')
df_exp3.shape
# Out:
# (5000, 2)

# %%
df_exp3['timeMs'] = df_exp3['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp3['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
df_exp3_ri = pd.read_csv('exp3-ri.csv', sep=';', )
df_exp3_ri.shape
# Out:
# (298, 1)

# %%
df_exp3_ri['timeMs'] = df_exp3_ri['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp3_ri['timeMs'])
ax.set_ylim(900, 1100)
# Out:
# (900.0, 1100.0)

# %% [markdown]
# ## Registration scalability with partitions (exp4)

# %%
df_exp4 = pd.read_csv('exp4.csv', sep=';')
df_exp4.shape
# Out:
# (5000, 2)

# %%
df_exp4['timeMs'] = df_exp4['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp4['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Registration scalability with MANY partitions (exp5)

# %%
df_exp5 = pd.read_csv('exp5.csv', sep=';')
df_exp5.shape
# Out:
# (5000, 2)

# %%
df_exp5['timeMs'] = df_exp5['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp5['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ### Exp5a (50 partitions)

# %%
df_exp5a = pd.read_csv('exp5a.csv', sep=';')
df_exp5a.shape
# Out:
# (5000, 2)

# %%
df_exp5a['timeMs'] = df_exp5a['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp5a['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
avg2a = df_exp2a['timeMs'].mean()
avg4 = df_exp4['timeMs'].mean()
avg5 = df_exp5['timeMs'].mean()
avg5a = df_exp5a['timeMs'].mean()

print('One partition ' + str(avg2a))
print('Two partition ' + str(avg4))
print('100 partition ' + str(avg5))
print('50 partition ' + str(avg5a))
# Out:
# One partition 40.079026211
# Two partition 31.922621598800003
# 100 partition 29.3740438368
# 50 partition 23.014745866999995

# %% [markdown]
# ## Two Actor Runtimes (exp6)

# %%
df_exp6 = pd.read_csv('exp6.csv', sep=';')
df_exp6.shape
# Out:
# (5000, 2)

# %%
df_exp6['timeMs'] = df_exp6['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp6['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
avg4 = df_exp4['timeMs'].mean()
avg6 = df_exp6['timeMs'].mean()
print('Two partition, one runtimes ' + str(avg4))
print('Two partition, two runtimes ' + str(avg6))
# Out:
# Two partition, one runtimes 31.922621598800003
# Two partition, two runtimes 35.1639403142

# %% [markdown]
# ### Two Actor Runtimes (exp6a, 50 partitions)

# %%
df_exp6a = pd.read_csv('exp6a.csv', sep=';')
df_exp6a.shape
# Out:
# (5000, 2)

# %%
df_exp6a['timeMs'] = df_exp6a['timeNs'] / 1000 / 1000
ax = sns.lineplot(data=df_exp6a['timeMs'])
ax.set_ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
avg5a = df_exp5a['timeMs'].mean()
avg6a = df_exp6a['timeMs'].mean()
print('50 partition, one runtimes ' + str(avg5a))
print('50 partition, two runtimes ' + str(avg6a))
# Out:
# 50 partition, one runtimes 23.014745866999995
# 50 partition, two runtimes 27.8189170512

# %% [markdown]
# ### Two Actor Runtimes (exp6b, repeat 6a)

# %%
df_exp6b = pd.read_csv('exp6b.csv', sep=';')
df_exp6b.shape
# Out:
# (5000, 2)

# %%
df_exp6b['timeMs'] = df_exp6b['timeNs'] / 1000 / 1000
avg6a = df_exp6a['timeMs'].mean()
avg6b = df_exp6b['timeMs'].mean()
print('50 partition, two runtimes ' + str(avg6a))
print('50 partition, two runtimes ' + str(avg6b))
# Out:
# 50 partition, two runtimes 27.8189170512
# 50 partition, two runtimes 26.7766634724
